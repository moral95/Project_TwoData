# %%
# !python butter_main.py

# %%
# !python main.py
# Out:
# {'training': {'batch_size': 16, 'learning_rate': 0.0001, 'num_epochs': 10, 'weight_decay': 0.01, 'grad_clip': 5.0, 'model': 'resnet50', 'optim': 'Adam', 'scheduler': 'StepLR', 'criterion': 'CEL', 'seed': 5657}, 'model': {'dropout_rate': 0.1, 'num_classes': 20}, 'paths': {'train_annot': '/NasData/home/lsh/10.project/data/butterfly/Training_set.csv', 'test_annot': '/NasData/home/lsh/10.project/data/butterfly/Testing_set.csv', 'model_save_path': './save/butter.pth', 'dataset_path': '/NasData/home/lsh/10.project/data/butterfly/'}}
# We used the cuda:2
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# ...
# 100%|█████████████████████████████████████████| 122/122 [00:15<00:00,  7.81it/s]
#
#               Epoch: 1/10..
#               Training Loss: 3.2357.. Training Accuracy: 28.56%.. Training F1 Score: 0.01
#
#
#               Epoch: 1/10..
#               Validation Loss: 2.3483.. Validation Accuracy: 18.67%.. Validation F1 Score: 0.11
#
# ...

# %%
# !python main.py

# %%
# !python main.py
# Out:
# {'training': {'batch_size': 128, 'learning_rate': 0.0001, 'num_epochs': 10, 'weight_decay': 0.01, 'grad_clip': 5.0, 'model': 'resnet50', 'optim': 'Adam', 'scheduler': 'StepLR', 'criterion': 'CEL', 'seed': 5657}, 'model': {'dropout_rate': 0.1, 'num_classes': 20}, 'paths': {'train_annot': '/NasData/home/lsh/10.project/data/butterfly/Training_set.csv', 'test_annot': '/NasData/home/lsh/10.project/data/butterfly/Testing_set.csv', 'model_save_path': './save/butter.pth', 'dataset_path': '/NasData/home/lsh/10.project/data/butterfly/'}}
# We used the cuda:2
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# ...
# 100%|███████████████████████████████████████████| 16/16 [00:10<00:00,  1.49it/s]
#
#               Epoch: 1/10..
#               Training Loss: 7.0932.. Training Accuracy: 12.09%.. Training F1 Score: 0.00
#
#
#               Epoch: 1/10..
#               Validation Loss: 4.7364.. Validation Accuracy: 14.82%.. Validation F1 Score: 0.05
#
# ...
